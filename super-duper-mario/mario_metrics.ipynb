# %%
import pandas as pd
import seaborn as sn

# %%
metrics = pd.read_csv("logs/lightning_logs/version_0/metrics.csv")
del metrics["step"]
metrics.set_index("epoch", inplace=True)
display(metrics.dropna(axis=1, how="all").head())
sn.relplot(data=metrics, kind="line")
# Out:
#        epsilon  episode reward  reward  train_loss  total_reward
# epoch
# 3      0.95149           -18.0    -2.0   17.548000           0.0
# 7      0.90199            57.0     3.0   14.842093           0.0
# 11     0.85249           294.0    -1.0    6.066189           0.0
# 15     0.80299           344.0    -2.0   20.691553           0.0
# 19     0.75349           323.0     4.0   17.615274           0.0
